# %%
from pathlib import Path
import pandas as pd

# %%
# File to Load (Remember to Change These)
sheet_name = 0
population_data_to_load_2021 = ("../Project_1/2021_GCP_SAL_for_VIC_short-header/2021 Census GCP Suburbs and Localities for VIC/2021Census_G03_VIC_SAL.csv")
suburb_name_data_to_load_2021 = ("../Project_1/2021_GCP_SAL_for_VIC_short-header/Metadata/2021Census_geog_desc_1st_2nd_3rd_release.xlsx")
#Reference:https://stackoverflow.com/questions/60700437/i-am-using-pandas-in-python-to-read-a-csv-how-do-i-pass-a-sheet-name-to-read-par

# %%
# Read population and Suburb data into Pandas DataFrames
population_data_2021 = pd.read_csv(population_data_to_load_2021)
suburb_name_data_2021 = pd.read_excel("../Project_1/2021_GCP_SAL_for_VIC_short-header/Metadata/2021Census_geog_desc_1st_2nd_3rd_release.xlsx", sheet_name = 5)

# %%
population_data_2021= population_data_2021.rename(columns={"SAL_CODE_2021":"Census_Code_2021"})
population_data_2021.head()
# Out:
#   Census_Code_2021  Count_home_Census_Nt_0_14_yr  \
# 0         SAL20001                             0
# 1         SAL20002                           705
# 2         SAL20003                           632
# 3         SAL20004                             0
# 4         SAL20005                            13
#
#    Count_hom_Census_Nt_15_24_yr  Count_hom_Census_Nt_25_34_yr  \
# 0                             0                             0
# 1                           816                          3164
# 2                           627                           344
# 3                             0                             0
# 4                             8                             7
#
#    Count_hom_Census_Nt_35_44_yr  Count_hom_Census_Nt_45_54_yr  \
# 0                             0                             0
# 1                          1707                           852
# 2                           455                           645
# ...

# %%
population_and_suburb_data_df = pd.merge(population_data_2021, suburb_name_data_2021, how = "left", on=["Census_Code_2021", "Census_Code_2021"])

# %%
population_data_2021.head()
# Out:
#   SAL_CODE_2021  Count_home_Census_Nt_0_14_yr  Count_hom_Census_Nt_15_24_yr  \
# 0      SAL20001                             0                             0
# 1      SAL20002                           705                           816
# 2      SAL20003                           632                           627
# 3      SAL20004                             0                             0
# 4      SAL20005                            13                             8
#
#    Count_hom_Census_Nt_25_34_yr  Count_hom_Census_Nt_35_44_yr  \
# 0                             0                             0
# 1                          3164                          1707
# 2                           344                           455
# 3                             0                             0
# 4                             7                             8
#
#    Count_hom_Census_Nt_45_54_yr  Count_hom_Census_Nt_55_64_yr  \
# 0                             0                             0
# ...

# %%
population_test = population_data_2021.loc[(population_data_2021["SAL_CODE_2021"] == "SAL20495"), :]

# %%
population_test
# Out:
#     SAL_CODE_2021  Count_home_Census_Nt_0_14_yr  Count_hom_Census_Nt_15_24_yr  \
# 494      SAL20495                           842                          4670
#
#      Count_hom_Census_Nt_25_34_yr  Count_hom_Census_Nt_35_44_yr  \
# 494                          5208                          1670
#
#      Count_hom_Census_Nt_45_54_yr  Count_hom_Census_Nt_55_64_yr  \
# 494                           923                           765
#
#      Count_hom_Census_Nt_65_74_yr  Count_hom_Census_Nt_75_84_yr  \
# 494                           630                           420
#
#      Count_hom_Census_Nt_85ov  ...  Total_0_14_yr  Total_15_24_yr  \
# 494                       200  ...            876            4860
#
#      Total_25_34_yr  Total_35_44_yr  Total_45_54_yr  Total_55_64_yr  \
# 494            5364            1739             972             811
#
#      Total_65_74_yr  Total_75_84_yr  Total_85ov  Total_Total
# 494             647             432         210        15896
#
# ...

# %%
suburb_name_data_2021.head()
# Out:
#   ASGS_Structure Census_Code_2021 AGSS_Code_2021 Census_Name_2021  \
# 0            AUS              AUS            AUS        AUSTRALIA
# 1            CED           CED101            101            Banks
# 2            CED           CED102            102           Barton
# 3            CED           CED103            103        Bennelong
# 4            CED           CED104            104          Berowra
#
#       Area sqkm
# 0  7.688095e+06
# 1  4.943710e+01
# 2  3.954700e+01
# 3  5.869100e+01
# 4  7.439867e+02

# %%
suburb_test = suburb_name_data_2021.loc[(suburb_name_data_2021["Census_Code_2021"] == "SAL20495"), :]

# %%
suburb_test
# Out:
#      ASGS_Structure Census_Code_2021 AGSS_Code_2021 Census_Name_2021  \
# 8867            SAL         SAL20495          20495   Carlton (Vic.)
#
#       Area sqkm
# 8867     1.7728

# %%
population_and_suburb_data_df.head()
# Out:
#   Census_Code_2021  Count_home_Census_Nt_0_14_yr  \
# 0         SAL20001                             0
# 1         SAL20002                           705
# 2         SAL20003                           632
# 3         SAL20004                             0
# 4         SAL20005                            13
#
#    Count_hom_Census_Nt_15_24_yr  Count_hom_Census_Nt_25_34_yr  \
# 0                             0                             0
# 1                           816                          3164
# 2                           627                           344
# 3                             0                             0
# 4                             8                             7
#
#    Count_hom_Census_Nt_35_44_yr  Count_hom_Census_Nt_45_54_yr  \
# 0                             0                             0
# 1                          1707                           852
# 2                           455                           645
# ...

# %%
#population_and_suburb_test = population_and_suburb_data_df.loc[(population_and_suburb_data_df["Census_Code_2021"] == "SAL20495")]
population_and_suburb_test = population_and_suburb_data_df.loc[(population_and_suburb_data_df["Census_Name_2021"] == "Tyabb")]

# %%
population_and_suburb_test.head()
# Out:
#      Census_Code_2021  Count_home_Census_Nt_0_14_yr  \
# 2593         SAL22594                           570
#
#       Count_hom_Census_Nt_15_24_yr  Count_hom_Census_Nt_25_34_yr  \
# 2593                           432                           406
#
#       Count_hom_Census_Nt_35_44_yr  Count_hom_Census_Nt_45_54_yr  \
# 2593                           351                           484
#
#       Count_hom_Census_Nt_55_64_yr  Count_hom_Census_Nt_65_74_yr  \
# 2593                           492                           349
#
#       Count_hom_Census_Nt_75_84_yr  Count_hom_Census_Nt_85ov  ...  \
# 2593                           182                        58  ...
#
#       Total_45_54_yr  Total_55_64_yr  Total_65_74_yr  Total_75_84_yr  \
# 2593             490             506             349             188
#
#       Total_85ov  Total_Total  ASGS_Structure  AGSS_Code_2021  \
# 2593          58         3411             SAL           22594
#
#       Census_Name_2021  Area sqkm
# ...
