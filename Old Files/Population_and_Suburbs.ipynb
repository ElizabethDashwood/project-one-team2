# %%
from pathlib import Path
import pandas as pd

# %%
# Files to Load
population_data_to_load_2021 = ("../Project_1/2021_GCP_SAL_for_VIC_short-header/2021 Census GCP Suburbs and Localities for VIC/2021Census_G03_VIC_SAL.csv")
suburb_name_data_to_load_2021 = ("../Project_1/2021_GCP_SAL_for_VIC_short-header/Metadata/2021Census_geog_desc_1st_2nd_3rd_release.xlsx")

# %%
# Read Population data into Pandas DataFrames
population_data_2021_df = pd.read_csv(population_data_to_load_2021)

# Read population and Suburb data into Pandas DataFrames and specifiy which worksheet number to be read in suburb file
sheet_name = 0
suburb_name_data_2021_df = pd.read_excel("../Project_1/2021_GCP_SAL_for_VIC_short-header/Metadata/2021Census_geog_desc_1st_2nd_3rd_release.xlsx", sheet_name = 5)
# Reference:https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html

# %%
# Test only: Check data load for population data
population_data_2021_df.head()
# Out:
#   SAL_CODE_2021  Count_home_Census_Nt_0_14_yr  Count_hom_Census_Nt_15_24_yr  \
# 0      SAL20001                             0                             0
# 1      SAL20002                           705                           816
# 2      SAL20003                           632                           627
# 3      SAL20004                             0                             0
# 4      SAL20005                            13                             8
#
#    Count_hom_Census_Nt_25_34_yr  Count_hom_Census_Nt_35_44_yr  \
# 0                             0                             0
# 1                          3164                          1707
# 2                           344                           455
# 3                             0                             0
# 4                             7                             8
#
#    Count_hom_Census_Nt_45_54_yr  Count_hom_Census_Nt_55_64_yr  \
# 0                             0                             0
# 1                           852                           645
# 2                           645                           585
# 3                             0                             0
# 4                            22                            16
#
#    Count_hom_Census_Nt_65_74_yr  Count_hom_Census_Nt_75_84_yr  \
# 0                             0                             0
# 1                           473                           238
# 2                           327                           138
# 3                             0                             0
# 4                            31                            19
#
#    Count_hom_Census_Nt_85ov  ...  Total_0_14_yr  Total_15_24_yr  \
# 0                         0  ...              0               0
# 1                        92  ...            720             843
# 2                        73  ...            633             634
# 3                         0  ...              0               0
# 4                         4  ...             13               8
#
#    Total_25_34_yr  Total_35_44_yr  Total_45_54_yr  Total_55_64_yr  \
# 0               0               0               0               0
# 1            3224            1750             885             662
# 2             353             459             653             588
# 3               0               0               0               0
# 4              16               8              20              19
#
#    Total_65_74_yr  Total_75_84_yr  Total_85ov  Total_Total
# 0               0               0           0            0
# 1             487             244          97         8916
# 2             333             142          73         3880
# 3               0               3           0           10
# 4              32              22           4          144
#
# [5 rows x 141 columns]

# %%
#Test only: Read an individual record for a population
population_test = population_data_2021_df.loc[(population_data_2021_df["SAL_CODE_2021"] == "SAL20495"), :]
population_test
# Out:
#     SAL_CODE_2021  Count_home_Census_Nt_0_14_yr  Count_hom_Census_Nt_15_24_yr  \
# 494      SAL20495                           842                          4670
#
#      Count_hom_Census_Nt_25_34_yr  Count_hom_Census_Nt_35_44_yr  \
# 494                          5208                          1670
#
#      Count_hom_Census_Nt_45_54_yr  Count_hom_Census_Nt_55_64_yr  \
# 494                           923                           765
#
#      Count_hom_Census_Nt_65_74_yr  Count_hom_Census_Nt_75_84_yr  \
# 494                           630                           420
#
#      Count_hom_Census_Nt_85ov  ...  Total_0_14_yr  Total_15_24_yr  \
# 494                       200  ...            876            4860
#
#      Total_25_34_yr  Total_35_44_yr  Total_45_54_yr  Total_55_64_yr  \
# 494            5364            1739             972             811
#
#      Total_65_74_yr  Total_75_84_yr  Total_85ov  Total_Total
# 494             647             432         210        15896
#
# [1 rows x 141 columns]

# %%
# Test only: Check data load for suburb data
suburb_name_data_2021_df.head()
# Out:
#   ASGS_Structure Census_Code_2021 AGSS_Code_2021 Census_Name_2021  \
# 0            AUS              AUS            AUS        AUSTRALIA
# 1            CED           CED101            101            Banks
# 2            CED           CED102            102           Barton
# 3            CED           CED103            103        Bennelong
# 4            CED           CED104            104          Berowra
#
#       Area sqkm
# 0  7.688095e+06
# 1  4.943710e+01
# 2  3.954700e+01
# 3  5.869100e+01
# 4  7.439867e+02

# %%
#Test only: Read an individual record for a suburb
suburb_test = suburb_name_data_2021_df.loc[(suburb_name_data_2021_df["Census_Code_2021"] == "SAL20495"), :]
suburb_test
# Out:
#      ASGS_Structure Census_Code_2021 AGSS_Code_2021 Census_Name_2021  \
# 8867            SAL         SAL20495          20495   Carlton (Vic.)
#
#       Area sqkm
# 8867     1.7728

# %%
# Rename column in Population data for allow DataFrames to merge
population_data_2021_df= population_data_2021_df.rename(columns={"SAL_CODE_2021":"Census_Code_2021"})
population_data_2021_df.head()
# Out:
#   Census_Code_2021  Count_home_Census_Nt_0_14_yr  \
# 0         SAL20001                             0
# 1         SAL20002                           705
# 2         SAL20003                           632
# 3         SAL20004                             0
# 4         SAL20005                            13
#
#    Count_hom_Census_Nt_15_24_yr  Count_hom_Census_Nt_25_34_yr  \
# 0                             0                             0
# 1                           816                          3164
# 2                           627                           344
# 3                             0                             0
# 4                             8                             7
#
#    Count_hom_Census_Nt_35_44_yr  Count_hom_Census_Nt_45_54_yr  \
# 0                             0                             0
# 1                          1707                           852
# 2                           455                           645
# 3                             0                             0
# 4                             8                            22
#
#    Count_hom_Census_Nt_55_64_yr  Count_hom_Census_Nt_65_74_yr  \
# 0                             0                             0
# 1                           645                           473
# 2                           585                           327
# 3                             0                             0
# 4                            16                            31
#
#    Count_hom_Census_Nt_75_84_yr  Count_hom_Census_Nt_85ov  ...  Total_0_14_yr  \
# 0                             0                         0  ...              0
# 1                           238                        92  ...            720
# 2                           138                        73  ...            633
# 3                             0                         0  ...              0
# 4                            19                         4  ...             13
#
#    Total_15_24_yr  Total_25_34_yr  Total_35_44_yr  Total_45_54_yr  \
# 0               0               0               0               0
# 1             843            3224            1750             885
# 2             634             353             459             653
# 3               0               0               0               0
# 4               8              16               8              20
#
#    Total_55_64_yr  Total_65_74_yr  Total_75_84_yr  Total_85ov  Total_Total
# 0               0               0               0           0            0
# 1             662             487             244          97         8916
# 2             588             333             142          73         3880
# 3               0               0               3           0           10
# 4              19              32              22           4          144
#
# [5 rows x 141 columns]

# %%
# Merge Population Data and Suburb Data DataFrames
population_and_suburb_merged_df = pd.merge(population_data_2021_df, suburb_name_data_2021_df, how = "left", on=["Census_Code_2021", "Census_Code_2021"])

# %%
# Test only: Read data after merge of Population and Suburb DataFrames
population_and_suburb_merged_df.head(499)
# Out:
#     Census_Code_2021  Count_home_Census_Nt_0_14_yr  \
# 0           SAL20001                             0
# 1           SAL20002                           705
# 2           SAL20003                           632
# 3           SAL20004                             0
# 4           SAL20005                            13
# ..               ...                           ...
# 494         SAL20495                           842
# 495         SAL20496                           609
# 496         SAL20497                             8
# 497         SAL20498                          2448
# 498         SAL20499                            31
#
#      Count_hom_Census_Nt_15_24_yr  Count_hom_Census_Nt_25_34_yr  \
# 0                               0                             0
# 1                             816                          3164
# 2                             627                           344
# 3                               0                             0
# 4                               8                             7
# ..                            ...                           ...
# 494                          4670                          5208
# 495                           784                          1655
# 496                             3                             4
# 497                          2009                          3787
# 498                            17                            23
#
#      Count_hom_Census_Nt_35_44_yr  Count_hom_Census_Nt_45_54_yr  \
# 0                               0                             0
# 1                            1707                           852
# 2                             455                           645
# 3                               0                             0
# 4                               8                            22
# ..                            ...                           ...
# 494                          1670                           923
# 495                           813                           609
# 496                             0                            16
# 497                          2795                          2043
# 498                            14                            15
#
#      Count_hom_Census_Nt_55_64_yr  Count_hom_Census_Nt_65_74_yr  \
# 0                               0                             0
# 1                             645                           473
# 2                             585                           327
# 3                               0                             0
# 4                              16                            31
# ..                            ...                           ...
# 494                           765                           630
# 495                           556                           477
# 496                            17                            14
# 497                          1714                          1337
# 498                            22                            26
#
#      Count_hom_Census_Nt_75_84_yr  Count_hom_Census_Nt_85ov  ...  \
# 0                               0                         0  ...
# 1                             238                        92  ...
# 2                             138                        73  ...
# 3                               0                         0  ...
# 4                              19                         4  ...
# ..                            ...                       ...  ...
# 494                           420                       200  ...
# 495                           241                        92  ...
# 496                             9                         7  ...
# 497                           871                       432  ...
# 498                            11                         0  ...
#
#      Total_45_54_yr  Total_55_64_yr  Total_65_74_yr  Total_75_84_yr  \
# 0                 0               0               0               0
# 1               885             662             487             244
# 2               653             588             333             142
# 3                 0               0               0               3
# 4                20              19              32              22
# ..              ...             ...             ...             ...
# 494             972             811             647             432
# 495             623             572             483             249
# 496              16              17              14               9
# 497            2071            1747            1359             885
# 498              15              22              26              11
#
#      Total_85ov  Total_Total  ASGS_Structure  AGSS_Code_2021  \
# 0             0            0             SAL           20001
# 1            97         8916             SAL           20002
# 2            73         3880             SAL           20003
# 3             0           10             SAL           20004
# 4             4          144             SAL           20005
# ..          ...          ...             ...             ...
# 494         210        15896             SAL           20495
# 495          92         5978             SAL           20496
# 496           4           85             SAL           20497
# 497         440        17700             SAL           20498
# 498           0          160             SAL           20499
#
#       Census_Name_2021  Area sqkm
# 0             Abbeyard   327.5008
# 1    Abbotsford (Vic.)     1.7405
# 2           Aberfeldie     1.5515
# 3            Aberfeldy    10.8319
# 4              Acheron    72.6602
# ..                 ...        ...
# 494     Carlton (Vic.)     1.7728
# 495      Carlton North     1.8709
# 496            Carlyle    35.8382
# 497           Carnegie     3.6873
# 498           Carngham    69.5311
#
# [499 rows x 145 columns]

# %%
# Test only: Read individual record after merge of Population and Suburb DataFrames
#population_and_suburb_test_df = population_and_suburb_merged_df.loc[(population_and_suburb_merged_df["Census_Code_2021"] == "SAL20495")]
population_and_suburb_test_df = population_and_suburb_merged_df.loc[(population_and_suburb_merged_df["Census_Name_2021"] == "Carlton (Vic.)")]

# %%
# Set Index to AGSS_Code_2021 and rename columns to meaningful headings
population_and_suburb_data_df = population_and_suburb_merged_df.set_index(["AGSS_Code_2021"])
population_and_suburb_data_df = population_and_suburb_data_df.rename(columns={"Total_Total":"Total_Population","Census_Name_2021":"Suburb_Name"})

# %%
# Test only: Check data after setiing index and renaming columns
population_and_suburb_data_df.head(495)
# Out:
#                Census_Code_2021  Count_home_Census_Nt_0_14_yr  \
# AGSS_Code_2021
# 20001                  SAL20001                             0
# 20002                  SAL20002                           705
# 20003                  SAL20003                           632
# 20004                  SAL20004                             0
# 20005                  SAL20005                            13
# ...                         ...                           ...
# 20491                  SAL20491                             0
# 20492                  SAL20492                           230
# 20493                  SAL20493                            27
# 20494                  SAL20494                            70
# 20495                  SAL20495                           842
#
#                 Count_hom_Census_Nt_15_24_yr  Count_hom_Census_Nt_25_34_yr  \
# AGSS_Code_2021
# 20001                                      0                             0
# 20002                                    816                          3164
# 20003                                    627                           344
# 20004                                      0                             0
# 20005                                      8                             7
# ...                                      ...                           ...
# 20491                                      0                             0
# 20492                                    106                           104
# 20493                                     18                            18
# 20494                                     31                            20
# 20495                                   4670                          5208
#
#                 Count_hom_Census_Nt_35_44_yr  Count_hom_Census_Nt_45_54_yr  \
# AGSS_Code_2021
# 20001                                      0                             0
# 20002                                   1707                           852
# 20003                                    455                           645
# 20004                                      0                             0
# 20005                                      8                            22
# ...                                      ...                           ...
# 20491                                      0                             3
# 20492                                    120                           142
# 20493                                     18                            23
# 20494                                     49                            68
# 20495                                   1670                           923
#
#                 Count_hom_Census_Nt_55_64_yr  Count_hom_Census_Nt_65_74_yr  \
# AGSS_Code_2021
# 20001                                      0                             0
# 20002                                    645                           473
# 20003                                    585                           327
# 20004                                      0                             0
# 20005                                     16                            31
# ...                                      ...                           ...
# 20491                                      0                             3
# 20492                                    173                           178
# 20493                                     33                            23
# 20494                                     60                            53
# 20495                                    765                           630
#
#                 Count_hom_Census_Nt_75_84_yr  Count_hom_Census_Nt_85ov  ...  \
# AGSS_Code_2021                                                          ...
# 20001                                      0                         0  ...
# 20002                                    238                        92  ...
# 20003                                    138                        73  ...
# 20004                                      0                         0  ...
# 20005                                     19                         4  ...
# ...                                      ...                       ...  ...
# 20491                                      6                         0  ...
# 20492                                     71                        14  ...
# 20493                                      3                         0  ...
# 20494                                     21                         0  ...
# 20495                                    420                       200  ...
#
#                 Total_35_44_yr  Total_45_54_yr  Total_55_64_yr  \
# AGSS_Code_2021
# 20001                        0               0               0
# 20002                     1750             885             662
# 20003                      459             653             588
# 20004                        0               0               0
# 20005                        8              20              19
# ...                        ...             ...             ...
# 20491                        0               3               0
# 20492                      126             146             176
# 20493                       18              23              34
# 20494                       54              70              59
# 20495                     1739             972             811
#
#                 Total_65_74_yr  Total_75_84_yr  Total_85ov  Total_Population  \
# AGSS_Code_2021
# 20001                        0               0           0                 0
# 20002                      487             244          97              8916
# 20003                      333             142          73              3880
# 20004                        0               3           0                10
# 20005                       32              22           4               144
# ...                        ...             ...         ...               ...
# 20491                        3               6           0                14
# 20492                      182              76          14              1165
# 20493                       23               3           0               162
# 20494                       53              21           0               379
# 20495                      647             432         210             15896
#
#                 ASGS_Structure        Suburb_Name  Area sqkm
# AGSS_Code_2021
# 20001                      SAL           Abbeyard   327.5008
# 20002                      SAL  Abbotsford (Vic.)     1.7405
# 20003                      SAL         Aberfeldie     1.5515
# 20004                      SAL          Aberfeldy    10.8319
# 20005                      SAL            Acheron    72.6602
# ...                        ...                ...        ...
# 20491                      SAL           Caringal    71.7752
# 20492                      SAL         Carisbrook   116.2721
# 20493                      SAL     Carlisle River   191.2386
# 20494                      SAL          Carlsruhe    38.3360
# 20495                      SAL     Carlton (Vic.)     1.7728
#
# [495 rows x 144 columns]

# %%
# Create final DataFrame with only the required columns
population_and_suburb_summary_data_df = population_and_suburb_data_df[["Census_Code_2021","Suburb_Name","Total_Population","Area sqkm"]]

# %%
# Test only: Check final DataFrame with required columns
population_and_suburb_summary_data_df.head()
# Out:
#                Census_Code_2021        Suburb_Name  Total_Population  \
# AGSS_Code_2021
# 20001                  SAL20001           Abbeyard                 0
# 20002                  SAL20002  Abbotsford (Vic.)              8916
# 20003                  SAL20003         Aberfeldie              3880
# 20004                  SAL20004          Aberfeldy                10
# 20005                  SAL20005            Acheron               144
#
#                 Area sqkm
# AGSS_Code_2021
# 20001            327.5008
# 20002              1.7405
# 20003              1.5515
# 20004             10.8319
# 20005             72.6602

# %%
# Test only: Read record for individual suburb by Suburb_Name
test_suburb_name_df = population_and_suburb_summary_data_df.loc[(population_and_suburb_summary_data_df["Suburb_Name"] ==  "Mulgrave (Vic.)")]  #"Carlton (Vic.)"

# %%
# Test only: Check record for individual suburb by Suburb_Name
test_suburb_name_df
# Out:
#                  AGSS_Code_2021      Suburb_Name  Total_Population  Area sqkm
# Census_Code_2021
# SAL21827                  21827  Mulgrave (Vic.)             19903    10.7328

# %%
# Test only: Read record for individual suburb by Census_Code_2021
test_Census_Code_2021_df = population_and_suburb_summary_data_df.loc[(population_and_suburb_summary_data_df["Census_Code_2021"] ==  "SAL20496")]

# %%
# Test only: Check record for individual suburb by Census_Code_2021
test_Census_Code_2021_df
# Out:
#                Census_Code_2021    Suburb_Name  Total_Population  Area sqkm
# AGSS_Code_2021
# 20496                  SAL20496  Carlton North              5978     1.8709

# %%
# Read of final Suburb and Population data
population_and_suburb_summary_data_df
# Out:
#                Census_Code_2021                             Suburb_Name  \
# AGSS_Code_2021
# 20001                  SAL20001                                Abbeyard
# 20002                  SAL20002                       Abbotsford (Vic.)
# 20003                  SAL20003                              Aberfeldie
# 20004                  SAL20004                               Aberfeldy
# 20005                  SAL20005                                 Acheron
# ...                         ...                                     ...
# 22942                  SAL22942                                 Yuulong
# 22943                  SAL22943                                 Zeerust
# 22944                  SAL22944                               Zumsteins
# 29494                  SAL29494                 No usual address (Vic.)
# 29797                  SAL29797  Migratory - Offshore - Shipping (Vic.)
#
#                 Total_Population  Area sqkm
# AGSS_Code_2021
# 20001                          0   327.5008
# 20002                       8916     1.7405
# 20003                       3880     1.5515
# 20004                         10    10.8319
# 20005                        144    72.6602
# ...                          ...        ...
# 22942                         42    52.1657
# 22943                        142    18.0294
# 22944                          0   256.5582
# 29494                          0     0.0000
# 29797                        565     0.0000
#
# [2946 rows x 4 columns]
